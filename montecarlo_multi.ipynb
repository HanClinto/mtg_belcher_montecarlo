# %%
import cards
import sys
import random
import time
import ipywidgets as widgets
import matplotlib.pyplot as plt
import datetime
import os
import multiprocessing as mp

from typing import List

# %%
deckrange = [
{'quant':1, 'min_quant':0, 'max_quant':4, 'name':"Arboreal Grazer"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Caravan Vigil"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Sakura-Tribe Elder"},
{'quant':1, 'min_quant':0, 'max_quant':4, 'name':"Lay of the Land"},
{'quant':2, 'min_quant':0, 'max_quant':8, 'name':"Elvish Mystic"},
{'quant':2, 'min_quant':0, 'max_quant':4, 'name':"Ancient Stirrings"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Reclaim the Wastes"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Wild Growth"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Land Grant"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Rampant Growth"},
{'quant':2, 'min_quant':0, 'max_quant':4, 'name':"Explore"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Wall of Roots"},
{'quant':3, 'min_quant':0, 'max_quant':4, 'name':"Search for Tomorrow"},
{'quant':3, 'min_quant':0, 'max_quant':4, 'name':"Nissa's Pilgrimage"},
{'quant':3, 'min_quant':0, 'max_quant':4, 'name':"Recross the Paths"},
{'quant':3, 'min_quant':0, 'max_quant':4, 'name':"Goblin Charbelcher"},
{'quant':4, 'min_quant':0, 'max_quant':4, 'name':"Chancellor of the Tangle"},
{'quant':7, 'min_quant':7, 'max_quant':7, 'name':"Forest"},
{'quant':1, 'min_quant':0, 'max_quant':1, 'name':"Panglacial Wurm"}
]

# %%
def get_deck_variants(deckrange):
    """Get all possible deck variants"""
    decks_61 = []
    cards_61 = []
    decks_59 = []
    cards_59 = []

    deck_baseline = ""
    for card in deckrange:
        deck_baseline += str(card['quant']) + " " + card['name'] + "\n"
    
    # 61-card decks
    for chosen_card in deckrange:
        deck = ""
        if chosen_card['quant'] < chosen_card['max_quant']:
            for card in deckrange:
                quant = card['quant']
                if card['name'] == chosen_card['name']:
                    quant += 1
                deck += str(quant) + " " + card['name'] + "\n"
            decks_61.append(deck)
            cards_61.append(chosen_card['name'])

    # 59-card decks
    for chosen_card in deckrange:
        deck = ""
        if chosen_card['quant'] > chosen_card['min_quant']:
            for card in deckrange:
                quant = card['quant']
                if card['name'] == chosen_card['name']:
                    quant -= 1
                deck += str(quant) + " " + card['name'] + "\n"
            decks_59.append(deck)
            cards_59.append(chosen_card['name'])

    return deck_baseline, decks_61, cards_61, decks_59, cards_59

# %%
deep_leaf = None
PRUNE_LIMIT = 1000 # Max number of leaf nodes that we support iterating through

def print_tree(state:cards.Player, depth = 0):
    print ("  "*depth, state.short_str())
    for child in state.childstates:
        print_tree(child, depth+1)

def get_all_leaf_nodes(state:cards.Player, depth=0) -> List[cards.Player]:
    global deep_leaf

    if state.is_pruned:
        return []

    if len(state.childstates) == 0:
        return [state]
    else:
        leaf_nodes = []
        for child in state.childstates:
            leaf_nodes.extend(get_all_leaf_nodes(child, depth+1))
        return leaf_nodes

def find_fastest_win(state:cards.Player, maxturn = 10):
    did_win = False
    win_state = None
    max_leaf_nodes = 0
    action_count = 0

    state.start_turn()
    
    # Track leaf nodes that are unique
    unique_leaf_nodes = {}

    while not did_win:
        action_count += 1
        leaf_nodes = get_all_leaf_nodes(state)
        
        if len(leaf_nodes) > max_leaf_nodes:
            max_leaf_nodes = len(leaf_nodes)

        # Find the minimum turn in the leaf nodes
        min_turn = min([leaf.current_turn for leaf in leaf_nodes])

        # Find any leaf nodes that are at the minimum turn
        min_turn_leaf_nodes = [leaf for leaf in leaf_nodes if leaf.current_turn == min_turn]

        # Find any leaf nodes where check_win() is True
        win_leaf_nodes = [leaf for leaf in min_turn_leaf_nodes if leaf.check_win()]

        if len(win_leaf_nodes) > 0:
            did_win = True
            win_state = win_leaf_nodes[0]
            break
        elif min_turn > maxturn:
            break
        
        next_min_turn_leaf_nodes = []
        # For each leaf node in the min_turn_leaf_node list, deduplicate states that have the same string representation
        for leaf in min_turn_leaf_nodes:
            string_rep = str(leaf)
            if string_rep not in unique_leaf_nodes:
                unique_leaf_nodes[str(leaf)] = leaf
                next_min_turn_leaf_nodes.append(leaf)
            else:
                leaf.is_pruned = True

        min_turn_leaf_nodes = next_min_turn_leaf_nodes
        
        #print(f'Deduplicated {len(min_turn_leaf_nodes)} leaf nodes to {len(unique_leaf_nodes)} leaf nodes')

        # For each leaf node that is 
        # If we have more than leaf_node_limit leaf nodes, randomly select leaf_node_limit of them
        leaf_node_limit = PRUNE_LIMIT
        excess = len(min_turn_leaf_nodes) - leaf_node_limit
        if excess > 0:
            #print(f'Warning: Exceeding leaf node limit of {leaf_node_limit} at turn {min_turn} with {len(min_turn_leaf_nodes)} leaf nodes')

            """
            # Print off five random leaf nodes
            for i in range(5):
                print(f'*** Random leaf node {i}:')
                random_leaf = random.choice(min_turn_leaf_nodes)
                print_tree(random_leaf)
                print(random_leaf)
                random_leaf.dumplog()
            """
            
            random.seed(state.randseed)
            # Randomly select a subset of leaf nodes to prune
            # Shuffle our list of leaf nodes
            random.shuffle(min_turn_leaf_nodes)
            
            # Select the second half of min_turn_leaf_nodes to be pruned
            prune_nodes = min_turn_leaf_nodes[leaf_node_limit:]
            for leaf in prune_nodes:
                leaf.is_pruned = True
            # The others are not pruned and are kept.
            min_turn_leaf_nodes = min_turn_leaf_nodes[:leaf_node_limit]

        # Step through all min_turn_leaf_nodes
        for leaf in min_turn_leaf_nodes:
            next_states = leaf.step_next_actions()
            for next_state in next_states:
                if next_state.check_win():
                    did_win = True
                    win_state = next_state
                    break
            if did_win:
                break
        
    return win_state, action_count, max_leaf_nodes

# %%
import time



def test_decklist(decklist, num_trials, max_turns, seed_base = 0):
    #end_reasons = {}
    durations = []
    total_turns = 0

    winning_log_messages = {}
    then = time.time()

    pool = mp.Pool(mp.cpu_count())
    # NOTE: Use a deterministic seed for testing performance improvements
    # Uncomment the following line to use a random seed
    seed_base = random.randint(0, 2**31-1)
    players = [cards.Player(decklist, seed_base + i) for i in range(num_trials)]
    results = pool.map(find_fastest_win, [player for player in players])
    pool.close()

    for i, result in enumerate(results):
        
        win_state, action_count, max_leaf_nodes = result

        won_turn = max_turns + 2
        end_reason = "Did not win in time"

        if win_state is not None:
            #print (f'  Found win in {action_count} actions and {win_state.current_turn} turns: {win_state.short_str()}')
            won_turn = win_state.current_turn
            end_reason = win_state.log[-1].strip()

            for log_message in win_state.log:
                log_message = log_message.strip()
                if log_message not in winning_log_messages:
                    winning_log_messages[log_message] = 0
                winning_log_messages[log_message] += 1
        else:
            #print (f'  Did not find win.  Max leaf nodes: {max_leaf_nodes}')
            pass

        total_turns += won_turn

        #if end_reason not in end_reasons:
        #    end_reasons[end_reason] = 1
        #else:
        #    end_reasons[end_reason] += 1

    duration = time.time() - then
    avg_duration = duration / num_trials

    avg_win_turn = total_turns / num_trials
    print (f' Average win turn: {avg_win_turn}')
    print (f' Tested decklist in {duration} ({avg_duration} each)')

    # Return the average winning turn number
    return avg_win_turn

# %%
def update_plots(baseline_wins, running_wins_61_avgs, running_wins_59_avgs, running_best_win, running_delta):
    # Create a plot of each decklist's average winning turn number
    plt.figure(figsize=(20,10))
    plt.plot(baseline_wins, label='Baseline')
    plt.plot(running_wins_61_avgs, label='61 card decklist')
    plt.plot(running_wins_59_avgs, label='59 card decklist')
    plt.plot(running_best_win, label='Best win')
    plt.plot(running_delta, label='Delta')
    plt.legend()
    plt.show()

# %%
epoch_num = 0
log_folder = ''

def run_epoch(deckrange, num_trials, max_turns, step_size):
    global epoch_num
    deck_baseline, decks_61, cards_61, decks_59, cards_59 = get_deck_variants(deckrange)
    wins_61 = {}
    wins_59 = {}
    baseline_wins = []
    epoch_num += 1
    tsv_filename = log_folder + f'epoch_{epoch_num}.tsv'
    with open(tsv_filename, 'w') as f:
        f.write('Trials\tAvg. Time Per Test\tBaseline\tBest Win\tDelta\tBest Card to Add\tBest Card to Remove\t')
        for card in cards_61:
            f.write(f"'+{card}'\t")
        for card in cards_59:
            f.write(f"'-{card}'\t")
        f.write('\n')
        f.flush()
    
    print (f'Running epoch {epoch_num} with {num_trials} trials and {max_turns} max turns.')
    simulations_per_step = (len(decks_61) + len(decks_59)) * step_size
    print (f' Total number of simulated games in this epoch: {num_trials * simulations_per_step}')
    for i in range(len(decks_61)):
        wins_61[i] = []
    for i in range(len(decks_59)):
        wins_59[i] = []
    print(f' Baseline decklist: {deck_baseline}')
    print(f' Number of 61-card decks: {len(decks_61)}')
    print(f' Number of 59-card decks: {len(decks_59)}')

    running_baseline_wins = []
    running_wins_61_avgs = []
    running_wins_59_avgs = []
    running_best_win = []
    running_delta = []
    running_durations = []

    for i in range(num_trials):
        print(f'Step {i+1}/{num_trials}:')
        then = time.time()
        print(f'Testing baseline')
        baseline_wins.append(test_decklist(deck_baseline, step_size, max_turns, seed_base = i * step_size))

        for deck_61_index, deck_61 in enumerate(decks_61):
            print(f' Testing addition of {cards_61[deck_61_index]}')
            wins_61[deck_61_index].append(test_decklist(deck_61, step_size, max_turns, seed_base = i * step_size))
        for deck_59_index, deck_59 in enumerate(decks_59):
            print(f' Testing removal of {cards_59[deck_59_index]}')
            wins_59[deck_59_index].append(test_decklist(deck_59, step_size, max_turns, seed_base = i * step_size))

        duration = time.time() - then
        avg_duration = duration / simulations_per_step

        wins_61_avgs = {}
        wins_59_avgs = {}
        for deck_61_index, deck_61 in enumerate(decks_61):
            wins_61_avgs[cards_61[deck_61_index]] = sum(wins_61[deck_61_index]) / len(wins_61[deck_61_index])
        for deck_59_index, deck_59 in enumerate(decks_59):
            wins_59_avgs[cards_59[deck_59_index]] = sum(wins_59[deck_59_index]) / len(wins_59[deck_59_index])

        # Sort the wins_61_avgs and wins_59_avgs by average winning turn
        wins_61_avgs = {k: v for k, v in sorted(wins_61_avgs.items(), key=lambda item: item[1])}
        wins_59_avgs = {k: v for k, v in sorted(wins_59_avgs.items(), key=lambda item: item[1])}

        baseline_wins_avg = sum(baseline_wins) / len(baseline_wins)

        running_wins_61_avgs.append(wins_61_avgs)
        running_wins_59_avgs.append(wins_59_avgs)
        running_baseline_wins.append(baseline_wins_avg)
        running_durations.append(avg_duration)

        # Print out the sorted list of cards and their average winning turn
        print(f' Baseline wins: {baseline_wins_avg}')
        print(f' Average duration: {avg_duration}')
        print(f'  Best cards to add:')
        for card, avg_win in wins_61_avgs.items():
            delta = avg_win - baseline_wins_avg
            if delta > 0:
                print(f'   {card}: +{delta}')
            else:
                print(f'   {card}: {delta}')
        print(f'  Best cards to remove:')
        for card, avg_win in wins_59_avgs.items():
            delta = avg_win - baseline_wins_avg
            if delta > 0:
                print(f'   {card}: +{delta}')
            else:
                print(f'   {card}: {delta}')

        # Get the best card to add and the best card to remove
        best_card_to_add = list(wins_61_avgs.keys())[0]
        best_card_to_remove = list(wins_59_avgs.keys())[0]

        # Average the win rate of the best 61-card deck and the best 59-card deck
        best_61_win = wins_61_avgs[best_card_to_add]
        best_59_win = wins_59_avgs[best_card_to_remove]
        best_win = (best_61_win + best_59_win) / 2

        print (f' Best card to add: {best_card_to_add} ({best_61_win})')
        print (f' Best card to remove: {best_card_to_remove} ({best_59_win})')
        delta = best_win - baseline_wins_avg
        print (f' Best win: {best_win} vs. {baseline_wins} ({delta})')

        running_best_win.append(best_win)
        running_delta.append(delta)

        #update_plots(baseline_wins, running_wins_61_avgs, running_wins_59_avgs, running_best_win, running_delta)

        # Output to TSV
        with open(tsv_filename, 'a') as f:
            f.write(f'{i*step_size}\t{avg_duration}\t{baseline_wins_avg}\t{best_win}\t{delta}\t{best_card_to_add}\t{best_card_to_remove}\t')
            for card in cards_61:
                f.write(f'{wins_61_avgs[card]}\t')
            for card in cards_59:
                f.write(f'{wins_59_avgs[card]}\t')
            f.write('\n')
            f.flush()

    return baseline_wins, best_win, best_card_to_add, best_card_to_remove

# %%
num_epochs = 20 # 1000
max_turns = 10 # 20
num_trials = 20 # 10000 # How many times to run a step of simulations within each epoch
step_size = 200 # How many times to run each deck in each step.
# Total number of simulations per epoch per deck will be: step_size * num_trials

# Log folder is named with the year, month, day, hour, minute, and second
log_folder = f'logs/output_prune{PRUNE_LIMIT}_turns{max_turns}_{datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")}/'
os.makedirs(log_folder)

for i in range(num_epochs):
    print(f'Epoch {i+1} of {num_epochs}')
    baseline_wins, best_win, best_card_to_add, best_card_to_remove = run_epoch(deckrange, num_trials, max_turns, step_size)
    
    # Find the card in deckrange that has this name and increase its quant
    for card in deckrange:
        if card['name'] == best_card_to_add:
            card['quant'] += 1
        if card['name'] == best_card_to_remove:
            card['quant'] -= 1
# Out:
# Epoch 1 of 20
# Running epoch 1 with 20 trials and 10 max turns.
#  Total number of simulated games in this epoch: 27000
#  Baseline decklist: 1 Arboreal Grazer
# 4 Caravan Vigil
# 4 Sakura-Tribe Elder
# 1 Lay of the Land
# 2 Elvish Mystic
# 2 Ancient Stirrings
# 4 Reclaim the Wastes
# 4 Wild Growth
# 4 Land Grant
# 4 Rampant Growth
# 2 Explore
# 4 Wall of Roots
# 3 Search for Tomorrow
# 3 Nissa's Pilgrimage
# 3 Recross the Paths
# 3 Goblin Charbelcher
# 4 Chancellor of the Tangle
# 7 Forest
# 1 Panglacial Wurm
#
#  Number of 61-card decks: 9
#  Number of 59-card decks: 18
# Step 1/20:
# Testing baseline
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 4/7 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 0/8 [1]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 7 turns: 7)  LID: 3  H: 3  Mana: 7/7 [0]  OLife: -7 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 24 actions and 8 turns: 8)  LID: 0  H: 7  Mana: 0/7 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 6 turns: 6)  LID: 0  H: 2  Mana: 5/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 6 turns: 6)  LID: 0  H: 5  Mana: 5/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 3/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 0/8 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 34 actions and 6 turns: 6)  LID: 0  H: 0  Mana: 2/10 [0]  OLife: -27 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 6/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 2/12 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 0/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 0  Mana: 1/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 3/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 4/7 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 7 turns: 7)  LID: 0  H: 6  Mana: 0/7 [1]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 4/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 4/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 3/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 31 actions and 6 turns: 6)  LID: 1  H: 3  Mana: 7/7 [0]  OLife: -1 '  Panglacial Wurm attacked for 9 and won the game'
#  Average win turn: 5.14
#  Tested decklist in 2.5303328037261963 (0.05060665607452393 each)
#  Testing addition of Arboreal Grazer
#   Did not find win.  Max leaf nodes: 1089
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 6/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 9 turns: 9)  LID: 0  H: 9  Mana: 4/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 4/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 10 turns: 10)  LID: 0  H: 8  Mana: 1/8 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 31 actions and 6 turns: 6)  LID: 0  H: 1  Mana: 6/9 [0]  OLife: -33 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 4/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/8 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 3/6 [2]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 7/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 6 turns: 6)  LID: 3  H: 3  Mana: 7/7 [0]  OLife: -4 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 16 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 9 turns: 9)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 6 turns: 6)  LID: 3  H: 3  Mana: 7/7 [0]  OLife: -1 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 8 turns: 8)  LID: 0  H: 5  Mana: 7/10 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 0/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 0/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 6 turns: 6)  LID: 0  H: 5  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 6  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 6 turns: 6)  LID: 0  H: 2  Mana: 8/8 [0]  OLife: -1 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 10 turns: 10)  LID: 0  H: 8  Mana: 0/8 [1]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 10 turns: 10)  LID: 0  H: 5  Mana: 4/11 [0]  OLife: -18 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Did not find win.  Max leaf nodes: 1
#  Average win turn: 5.76
#  Tested decklist in 2.9790802001953125 (0.05958160400390625 each)
#  Testing addition of Lay of the Land
#   Found win in 30 actions and 6 turns: 6)  LID: 0  H: 1  Mana: 4/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 7/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 6 turns: 6)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 30 actions and 6 turns: 6)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -35 '  Belcher with 0 lands in deck'
#   Found win in 33 actions and 10 turns: 10)  LID: 0  H: 2  Mana: 4/11 [0]  OLife: -33 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 7/10 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 5/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 0  Mana: 3/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 10 turns: 10)  LID: 0  H: 5  Mana: 2/9 [0]  OLife: -18 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 35 actions and 7 turns: 7)  LID: 0  H: 3  Mana: 9/9 [0]  OLife: -4 '  Chancellor of the Tangle attacked for 6 and won the game'
#   Found win in 31 actions and 9 turns: 9)  LID: 0  H: 3  Mana: 4/11 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/6 [2]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 0/8 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 0  Mana: 2/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 8 turns: 8)  LID: 0  H: 6  Mana: 2/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 3/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/7 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 4/11 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 7/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 8 turns: 8)  LID: 0  H: 6  Mana: 1/8 [1]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 0/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 30 actions and 6 turns: 6)  LID: 0  H: 0  Mana: 4/11 [0]  OLife: -35 '  Belcher with 0 lands in deck'
#   Found win in 35 actions and 8 turns: 8)  LID: 0  H: 1  Mana: 10/10 [0]  OLife: -4 '  Chancellor of the Tangle attacked for 6 and won the game'
#   Found win in 19 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 4/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 3/10 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 9 turns: 9)  LID: 0  H: 5  Mana: 2/9 [1]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#  Average win turn: 5.56
#  Tested decklist in 2.810359239578247 (0.05620718479156494 each)
#  Testing addition of Elvish Mystic
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 15 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/6 [2]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 9 turns: 9)  LID: 0  H: 5  Mana: 2/9 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 6 turns: 6)  LID: 0  H: 2  Mana: 7/10 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 3/6 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 8 turns: 8)  LID: 0  H: 6  Mana: 4/7 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 3/10 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 7 turns: 7)  LID: 0  H: 2  Mana: 3/10 [0]  OLife: -28 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 2/9 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 0  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 3/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 7 turns: 7)  LID: 0  H: 6  Mana: 5/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 7 turns: 7)  LID: 0  H: 6  Mana: 4/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 0/8 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 30 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 4/11 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 6 turns: 6)  LID: 0  H: 6  Mana: 0/7 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 15 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 31 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 3/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 6 turns: 6)  LID: 0  H: 2  Mana: 9/9 [0]  OLife: -1 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 27 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 6/9 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 8 turns: 8)  LID: 0  H: 5  Mana: 2/9 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 3/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#  Average win turn: 5.3
#  Tested decklist in 1.6907439231872559 (0.03381487846374512 each)
#  Testing addition of Ancient Stirrings
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/11 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 4/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 33 actions and 7 turns: 7)  LID: 1  H: 1  Mana: 11/11 [0]  OLife: -7 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 8/11 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 4/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 3/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 32 actions and 6 turns: 6)  LID: 0  H: 0  Mana: 2/10 [0]  OLife: -34 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 6/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 2/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 0/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 6 turns: 6)  LID: 2  H: 2  Mana: 8/8 [0]  OLife: -1 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 36 actions and 7 turns: 7)  LID: 0  H: 1  Mana: 12/12 [0]  OLife: -4 '  Chancellor of the Tangle attacked for 6 and won the game'
#   Found win in 31 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 3/10 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Did not find win.  Max leaf nodes: 1
#   Found win in 25 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 3/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 4/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 7/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 3/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 1/5 [2]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#  Average win turn: 5.18
#  Tested decklist in 1.1132290363311768 (0.022264580726623535 each)
#  Testing addition of Explore
#   Found win in 33 actions and 8 turns: 8)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 4/7 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Did not find win.  Max leaf nodes: 1
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 4/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 7 turns: 7)  LID: 0  H: 7  Mana: 4/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 6 turns: 6)  LID: 0  H: 5  Mana: 1/8 [1]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 0/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 4/7 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Did not find win.  Max leaf nodes: 1
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 3/6 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 6/9 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 42 actions and 7 turns: 7)  LID: 0  H: 2  Mana: 3/10 [0]  OLife: -33 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 6 turns: 6)  LID: 0  H: 1  Mana: 7/10 [0]  OLife: -35 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 0/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 4/10 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Did not find win.  Max leaf nodes: 1
#   Found win in 22 actions and 8 turns: 8)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 7/10 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 0/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 1/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 3/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 0/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 6 turns: 6)  LID: 0  H: 5  Mana: 4/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 7 turns: 7)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Did not find win.  Max leaf nodes: 220
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 0/9 [0]  OLife: -28 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 3/10 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 0/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#  Average win turn: 5.64
#  Tested decklist in 2.220811128616333 (0.044416222572326663 each)
#  Testing addition of Search for Tomorrow
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 8 turns: 8)  LID: 0  H: 6  Mana: 1/8 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 31 actions and 6 turns: 6)  LID: 2  H: 2  Mana: 8/8 [0]  OLife: -4 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 10 turns: 10)  LID: 0  H: 5  Mana: 3/10 [0]  OLife: -19 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 4 turns: 4)  LID: 0  H: 0  Mana: 0/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 6 turns: 6)  LID: 0  H: 5  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 7 turns: 7)  LID: 0  H: 3  Mana: 0/10 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 3/6 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 0/12 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 5/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 4/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 6 turns: 6)  LID: 0  H: 1  Mana: 7/10 [0]  OLife: -33 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 6 turns: 6)  LID: 0  H: 6  Mana: 4/7 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 0/12 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 3/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 14 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 0/8 [1]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 3/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 7 turns: 7)  LID: 0  H: 6  Mana: 4/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 9 turns: 9)  LID: 0  H: 7  Mana: 5/8 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 15 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 6 turns: 6)  LID: 2  H: 2  Mana: 7/7 [0]  OLife: -1 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 3/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 2/9 [1]  OLife: -21 '  Belcher with 0 lands in deck'
#   Did not find win.  Max leaf nodes: 32
#  Average win turn: 5.34
#  Tested decklist in 1.628526210784912 (0.03257052421569824 each)
#  Testing addition of Nissa's Pilgrimage
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 30 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 5 turns: 5)  LID: 0  H: 0  Mana: 3/10 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 4/7 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 4/7 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 6 turns: 6)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 8 turns: 8)  LID: 0  H: 5  Mana: 0/11 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 1/9 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 7 turns: 7)  LID: 0  H: 3  Mana: 4/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 6 turns: 6)  LID: 0  H: 6  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 0/7 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 2/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 3/10 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 23 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 7/7 [0]  OLife: -4 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 20 actions and 6 turns: 6)  LID: 0  H: 5  Mana: 0/7 [1]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 3/9 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 7/10 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 8 turns: 8)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 5 turns: 5)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 4 turns: 4)  LID: 0  H: 1  Mana: 1/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [1]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 29 actions and 6 turns: 6)  LID: 2  H: 3  Mana: 7/7 [0]  OLife: -1 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 1/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 1/8 [0]  OLife: -25 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 0/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 30 actions and 7 turns: 7)  LID: 2  H: 1  Mana: 9/9 [0]  OLife: -7 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 25 actions and 7 turns: 7)  LID: 0  H: 5  Mana: 0/8 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 17 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 4/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#  Average win turn: 5.38
#  Tested decklist in 2.2178773880004883 (0.04435754776000977 each)
#  Testing addition of Recross the Paths
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -26 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 5  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
# ...
#   Found win in 23 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 6 turns: 6)  LID: 0  H: 1  Mana: 5/8 [0]  OLife: -33 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 5/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 1/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 14 actions and 4 turns: 4)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -24 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 6/9 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 6 turns: 6)  LID: 0  H: 2  Mana: 9/9 [0]  OLife: -4 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 28 actions and 6 turns: 6)  LID: 0  H: 0  Mana: 1/10 [0]  OLife: -30 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 6 turns: 6)  LID: 0  H: 5  Mana: 0/8 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 5/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 24 actions and 6 turns: 6)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 28 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 6/9 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 26 actions and 7 turns: 7)  LID: 0  H: 4  Mana: 8/8 [0]  OLife: -7 '  Panglacial Wurm attacked for 9 and won the game'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 1/8 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/10 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 20 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 6 turns: 6)  LID: 0  H: 0  Mana: 5/11 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 16 actions and 4 turns: 4)  LID: 0  H: 3  Mana: 0/7 [0]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 25 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 7/10 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 1  Mana: 2/9 [0]  OLife: -29 '  Belcher with 0 lands in deck'
#   Found win in 27 actions and 8 turns: 8)  LID: 0  H: 4  Mana: 2/9 [1]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -21 '  Belcher with 0 lands in deck'
#   Found win in 21 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 2/8 [0]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 33 actions and 7 turns: 7)  LID: 0  H: 1  Mana: 11/11 [0]  OLife: -4 '  Chancellor of the Tangle attacked for 6 and won the game'
#   Found win in 23 actions and 4 turns: 4)  LID: 0  H: 2  Mana: 0/7 [1]  OLife: -22 '  Belcher with 0 lands in deck'
#   Found win in 22 actions and 5 turns: 5)  LID: 0  H: 4  Mana: 0/7 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#   Found win in 18 actions and 5 turns: 5)  LID: 0  H: 3  Mana: 0/7 [1]  OLife: -23 '  Belcher with 0 lands in deck'
#   Found win in 19 actions and 7 turns: 7)  LID: 0  H: 6  Mana: 0/7 [0]  OLife: -20 '  Belcher with 0 lands in deck'
#  Average win turn: 5.46
#  Tested decklist in 2.467266798019409 (0.04934533596038818 each)
#  Testing removal of Wall of Roots
# Process ForkPoolWorker-6076:
# Process ForkPoolWorker-6074:
# Process ForkPoolWorker-6079:
# Process ForkPoolWorker-6071:
# Process ForkPoolWorker-6077:
# Process ForkPoolWorker-6080:
# Process ForkPoolWorker-6073:
# Process ForkPoolWorker-6078:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-9e7481662b29>", line 102, in find_fastest_win
#     next_states = leaf.step_next_actions()
#   File "<ipython-input-4-9e7481662b29>", line 102, in find_fastest_win
#     next_states = leaf.step_next_actions()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-4-9e7481662b29>", line 36, in find_fastest_win
#     leaf_nodes = get_all_leaf_nodes(state)
#   File "<ipython-input-4-9e7481662b29>", line 102, in find_fastest_win
#     next_states = leaf.step_next_actions()
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 352, in step_next_actions
#     copy = self.copy()
# KeyboardInterrupt
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 327, in step_next_actions
#     copy = self.copy()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-4-9e7481662b29>", line 20, in get_all_leaf_nodes
#     leaf_nodes.extend(get_all_leaf_nodes(child, depth+1))
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 352, in step_next_actions
#     copy = self.copy()
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 363, in copy
#     copy = Player.deserialize(ser)
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 363, in copy
#     copy = Player.deserialize(ser)
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 363, in copy
#     copy = Player.deserialize(ser)
#   File "<ipython-input-4-9e7481662b29>", line 20, in get_all_leaf_nodes
#     leaf_nodes.extend(get_all_leaf_nodes(child, depth+1))
# Process ForkPoolWorker-6075:
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 376, in deserialize
#     return pickle.loads(ser)
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 376, in deserialize
#     return pickle.loads(ser)
#   File "<ipython-input-4-9e7481662b29>", line 20, in get_all_leaf_nodes
#     leaf_nodes.extend(get_all_leaf_nodes(child, depth+1))
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 376, in deserialize
#     return pickle.loads(ser)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   [Previous line repeated 10 more times]
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-6072:
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-4-9e7481662b29>", line 9, in get_all_leaf_nodes
#     def get_all_leaf_nodes(state:cards.Player, depth=0) -> List[cards.Player]:
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-9e7481662b29>", line 102, in find_fastest_win
#     next_states = leaf.step_next_actions()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 293, in step_next_actions
#     copy = self.copy()
#   File "/Users/clint/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 363, in copy
#     copy = Player.deserialize(ser)
#   File "<ipython-input-4-9e7481662b29>", line 102, in find_fastest_win
#     next_states = leaf.step_next_actions()
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 376, in deserialize
#     return pickle.loads(ser)
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 327, in step_next_actions
#     copy = self.copy()
# KeyboardInterrupt
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 363, in copy
#     copy = Player.deserialize(ser)
#   File "/Users/clint/github/mtg_montecarlo/cards.py", line 376, in deserialize
#     return pickle.loads(ser)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cc2407215a29> in <module>
#      11 for i in range(num_epochs):
#      12     print(f'Epoch {i+1} of {num_epochs}')
# ---> 13     baseline_wins, best_win, best_card_to_add, best_card_to_remove = run_epoch(deckrange, num_trials, max_turns, step_size)
#      14
#      15     # Find the card in deckrange that has this name and increase its quant
#
# <ipython-input-7-1f4e4c0fcd3f> in run_epoch(deckrange, num_trials, max_turns, step_size)
#      48         for deck_59_index, deck_59 in enumerate(decks_59):
#      49             print(f' Testing removal of {cards_59[deck_59_index]}')
# ---> 50             wins_59[deck_59_index].append(test_decklist(deck_59, step_size, max_turns, seed_base = i * step_size))
#      51
#      52         duration = time.time() - then
#
# <ipython-input-5-c73bee8df2b6> in test_decklist(decklist, num_trials, max_turns, seed_base)
#      16     seed_base = random.randint(0, 2**31-1)
#      17     players = [cards.Player(decklist, seed_base + i) for i in range(num_trials)]
# ---> 18     results = pool.map(find_fastest_win, [player for player in players])
#      19     pool.close()
#      20
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/opt/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/opt/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
